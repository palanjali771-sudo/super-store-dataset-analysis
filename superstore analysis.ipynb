# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\palan\OneDrive\Documents\superstore 2.xlsx")
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
customer = df[df["City"]== "Los Angeles "]
high_cus = customer.groupby("Customer Name")["Sales"].sum().sort_values(ascending = False).head()
high_cus
# Out:
# Series([], Name: Sales, dtype: float64)

# %%
customer = df[df["City"]== "Los Angeles"]
high_cus = customer.groupby("Customer Name")["Sales"].sum().sort_values(ascending= False).head(5)
print(high_cus)
# Out:
# Customer Name
# Robert Marley          4881.132
# Clay Ludtke            4409.020
# Karen Ferguson         4173.812
# Maribeth Schnelling    4104.174
# Sarah Brown            3862.098
# Name: Sales, dtype: float64

# %%
high_cus.plot(kind = "bar" , color = "black")
plt.title("highest customer from los angeles")
plt.ylabel("total sales")
plt.show()

# %%
 import matplotlib.pyplot as plt

# %% [markdown]
# #q2

# %%
segment = df.groupby("Segment")["Sales"].sum().sort_values(ascending = False)
print(segment)
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
segment.plot(kind = "bar")
plt.title("biggest segment by sales")
# Out:
# Text(0.5, 1.0, 'biggest segment by sales')

# %% [markdown]
# #q3

# %%
top_states = df.groupby("State")["Sales"].sum().sort_values(ascending = False).head(3)
print(top_states)
# Out:
# State
# California    457687.6315
# New York      310876.2710
# Texas         170188.0458
# Name: Sales, dtype: float64

# %%
top_states.plot(kind = "pie" , autopct = "%.f%%")
plt.title("top states by profit")
# Out:
# Text(0.5, 1.0, 'top states by profit')

# %% [markdown]
# ### q4

# %%
big_cus = df.groupby("Customer Name")["Sales"].sum().sort_values(ascending = False).head(3)
print(big_cus)
# Out:
# Customer Name
# Sean Miller     25043.050
# Tamara Chand    19052.218
# Raymond Buch    15117.339
# Name: Sales, dtype: float64

# %%
big_cus.plot(kind = "pie", autopct = "%.f%%")
plt.title("biggest customer by sales")
# Out:
# Text(0.5, 1.0, 'biggest customer by sales')

# %%
region = df.groupby("Region")["Sales"].sum().sort_values(ascending = False ).head(3)
print(region)
# Out:
# Region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# Name: Sales, dtype: float64

# %%
region.plot(kind = "pie", autopct = "%.f%%")
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# ### q6

# %%
high_pro = df[df["City"]=="Henderson"].groupby("Product Name")["City"].sum().sort_values(ascending = False).head(5)
print(high_pro)
# Out:
# Product Name
# Global Adaptabilities Conference Tables                        HendersonHenderson
# Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back    HendersonHenderson
# Magna Visual Magnetic Picture Hangers                          HendersonHenderson
# 3M Polarizing Task Lamp with Clamp Arm, Light Gray                      Henderson
# Global Deluxe High-Back Manager's Chair                                 Henderson
# Name: City, dtype: object

# %% [markdown]
# ### q7

# %%
top_sub = df.groupby("Sub-Category")[["Sales" ,"Profit"]].sum().sort_values(by = "Profit" , ascending = False).head(10)
print(top_sub)
# Out:
#                    Sales      Profit
# Sub-Category
# Copiers       149528.030  55617.8249
# Phones        330007.054  44515.7306
# Accessories   167380.318  41936.6357
# Paper          78479.206  34053.5693
# Binders       203412.733  30221.7633
# Chairs        328449.103  26590.1663
# Storage       223843.608  21278.8264
# Appliances    107532.161  18138.0054
# Furnishings    91705.164  13059.1436
# Envelopes      16476.402   6964.1767

# %%
plt.figure(figsize = (8,5))
plt.bar( top_sub.index , top_sub["Profit"] , color = "black")
plt.title("sales and profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# ### q8

# %%
shipment = df.groupby("Ship Mode")["Sales"].sum().sort_values(ascending = False).head(3)
print(shipment)
# Out:
# Ship Mode
# Standard Class    1.358216e+06
# Second Class      4.591936e+05
# First Class       3.514284e+05
# Name: Sales, dtype: float64

# %%
shipment.plot(kind = "pie" , autopct = "%.f%%")
plt.title("top shipment")
# Out:
# Text(0.5, 1.0, 'top shipment')

# %% [markdown]
# ### q9

# %%
top_cities = df.groupby("City")["Profit"].sum().sort_values(ascending = False).head(5)
print(top_cities)
# Out:
# City
# New York City    62036.9837
# Los Angeles      30440.7579
# Seattle          29156.0967
# San Francisco    17507.3854
# Detroit          13181.7908
# Name: Profit, dtype: float64

# %%
top_cities.plot(kind = "bar")
plt.title("most profitable cities")
# Out:
# Text(0.5, 1.0, 'most profitable cities')

# %%
worst_city = df.groupby("City")["Profit"].sum().sort_values(ascending = False).tail(5)
print(top_cities)
# Out:
# City
# New York City    62036.9837
# Los Angeles      30440.7579
# Seattle          29156.0967
# San Francisco    17507.3854
# Detroit          13181.7908
# Name: Profit, dtype: float64

# %%
worst_city.plot(kind = "bar")
plt.title("worst cities")
# Out:
# Text(0.5, 1.0, 'worst cities')
